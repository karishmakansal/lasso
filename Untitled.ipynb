# %% [markdown]
# # Assignment-1

# %% [markdown]
# # Name - Karishma Kansal
#         Uid-18bcs6103

# %%
# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Now we are inserting all libraries which are required in this program

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
import os

# %% [markdown]
# Now we are reading or extracting data which is required.

# %%
car= pd.read_csv('cars_trucks_and_buses_per_1000_persons.csv',encoding="latin-1")

# %%
car.head()
# Out:
#            geo  2002  2003  2004  2005  2006   2007
# 0  Afghanistan   NaN   NaN   NaN   NaN   NaN   22.8
# 1      Albania  73.0   NaN  85.0  87.5  97.3  102.0
# 2      Algeria   NaN  88.0  89.0  91.0   NaN    NaN
# 3       Angola   NaN   NaN   NaN   NaN   NaN   39.6
# 4    Argentina   NaN   NaN   NaN   NaN   NaN  314.0

# %%
co2=pd.read_csv('co2_emissions_tonnes_per_person.csv',index_col='geo')
co2.head()
# Out:
#              1800  1801  1802  1803  1804  1805  1806  1807  1808  1809  \
# geo
# Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Algeria       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Andorra       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Angola        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#              ...      2005    2006    2007   2008   2009   2010   2011  2012  \
# geo          ...
# Afghanistan  ...    0.0529  0.0637  0.0854  0.154  0.242  0.294  0.412  0.35
# Albania      ...    1.3800  1.2800  1.3000  1.460  1.480  1.560  1.790  1.68
# Algeria      ...    3.2200  2.9900  3.1900  3.160  3.420  3.300  3.290  3.46
# Andorra      ...    7.3000  6.7500  6.5200  6.430  6.120  6.120  5.870  5.92
# Angola       ...    0.9800  1.1000  1.2000  1.180  1.230  1.240  1.250  1.33
#
#               2013   2014
# geo
# Afghanistan  0.316  0.299
# Albania      1.730  1.960
# Algeria      3.510  3.720
# Andorra      5.900  5.830
# Angola       1.250  1.290
#
# [5 rows x 215 columns]

# %%
co2.rename(columns = {'2014':'co2_emissions_tonnes_per_person'}, inplace = True)

# %%
d1=co2.pop('co2_emissions_tonnes_per_person')
d1.head()
# Out:
# geo
# Afghanistan    0.299
# Albania        1.960
# Algeria        3.720
# Andorra        5.830
# Angola         1.290
# Name: co2_emissions_tonnes_per_person, dtype: float64

# %%
df1=pd.DataFrame(d1)
df1.head()
# Out:
#              co2_emissions_tonnes_per_person
# geo
# Afghanistan                            0.299
# Albania                                1.960
# Algeria                                3.720
# Andorra                                5.830
# Angola                                 1.290

# %%
coal=pd.read_csv('coal_consumption_per_cap.csv',index_col='geo')

# %%
coal.head()
# Out:
#                1965     1966     1967    1968     1969    1970     1971  \
# geo
# Algeria     0.00554  0.00524  0.00389  0.0040  0.00495  0.0057  0.00154
# Argentina   0.03570  0.03690  0.03560  0.0282  0.03710  0.0409  0.03310
# Australia   1.53000  1.55000  1.55000  1.5500  1.57000  1.5500  1.53000
# Austria     0.69600  0.66000  0.62100  0.6100  0.59700  0.6390  0.58300
# Azerbaijan      NaN      NaN      NaN     NaN      NaN     NaN      NaN
#
#               1972     1973     1974   ...        2007     2008     2009  \
# geo                                    ...
# Algeria     0.0013  0.00146  0.00117   ...     0.02210  0.02170  0.01370
# Argentina   0.0291  0.03010  0.03800   ...     0.03050  0.03450  0.02340
# Australia   1.5700  1.61000  1.66000   ...     2.51000  2.57000  2.44000
# Austria     0.5270  0.52200  0.54900   ...     0.47000  0.45000  0.34400
# Azerbaijan     NaN      NaN      NaN   ...     0.00014  0.00079  0.00046
#
#                2010     2011     2012     2013     2014     2015     2016
# geo
# Algeria     0.00858  0.00747  0.00777  0.00412  0.00458  0.00361  0.00356
# Argentina   0.03080  0.03720  0.03110  0.02950  0.03460  0.03130  0.02410
# Australia   2.23000  2.14000  1.98000  1.86000  1.82000  1.85000  1.82000
# Austria     0.40200  0.41000  0.37900  0.38200  0.34700  0.37300  0.36400
# Azerbaijan  0.00006  0.00038  0.00006  0.00031  0.00017  0.00004  0.00004
#
# [5 rows x 52 columns]

# %%
coal.rename(columns = {'2014':'coal_consumption_per_cap'}, inplace = True)

# %%
d2=coal.pop('coal_consumption_per_cap')
d2.head()
# Out:
# geo
# Algeria       0.00458
# Argentina     0.03460
# Australia     1.82000
# Austria       0.34700
# Azerbaijan    0.00017
# Name: coal_consumption_per_cap, dtype: float64

# %%
df2=pd.DataFrame(d2)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 65 entries, Algeria to Vietnam
# Data columns (total 1 columns):
# coal_consumption_per_cap    65 non-null float64
# dtypes: float64(1)
# memory usage: 1.0+ KB

# %%
df2.head()
# Out:
#             coal_consumption_per_cap
# geo
# Algeria                      0.00458
# Argentina                    0.03460
# Australia                    1.82000
# Austria                      0.34700
# Azerbaijan                   0.00017

# %%
electricity_gen=pd.read_csv('electricity_generation_per_person.csv',index_col='geo' )
electricity_gen.head()
# Out:
#               1985    1986    1987    1988    1989    1990    1991  1992  \
# geo
# Algeria      544.0   559.0   532.0   568.0   607.0   621.0   653.0   673
# Argentina   1490.0  1590.0  1660.0  1670.0  1580.0  1560.0  1620.0  1680
# Australia   7860.0  8100.0  8360.0  8670.0  9020.0  9130.0  9150.0  9230
# Austria     5850.0  5860.0  6610.0  6400.0  6530.0  6530.0  6620.0  6540
# Azerbaijan  3110.0  3180.0  3320.0  3360.0  3270.0  3200.0  3170.0  2630
#
#             1993    1994  ...     2007   2008   2009   2010   2011   2012  \
# geo                       ...
# Algeria      699   701.0  ...     1090   1150   1220   1270   1440   1530
# Argentina   1810  1890.0  ...     2880   3190   3180   3210   3110   3230
# Australia   9350  9510.0  ...    11600  11500  11500  11300  11400  11000
# Austria     6670  6710.0  ...     7800   8030   8250   8450   7780   8500
# Azerbaijan  2520  2290.0  ...     2500   2450   2110   2070   2220   2480
#
#              2013   2014   2015   2016
# geo
# Algeria      1560   1640   1730   1730
# Argentina    3280   3290   3350   3350
# Australia   10800  10500  10600  10600
# Austria      7930   7540   7480   7760
# Azerbaijan   2490   2600   2570   2570
#
# [5 rows x 32 columns]

# %%
electricity_gen.rename(columns = {'2014':'electricity_generation_per_person'}, inplace = True)

# %%
d3=electricity_gen.pop('electricity_generation_per_person')

# %%
df3=pd.DataFrame(d3)
df3.head()
# Out:
#             electricity_generation_per_person
# geo
# Algeria                                  1640
# Argentina                                3290
# Australia                               10500
# Austria                                  7540
# Azerbaijan                               2600

# %%
electircity_use=pd.read_csv('electricity_use_per_person.csv',index_col='geo')
electircity_use.head()
# Out:
#            1960  1961  1962  1963  1964  1965  1966  1967  1968  1969   ...    \
# geo                                                                     ...
# Albania     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   ...
# Algeria     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   ...
# Angola      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   ...
# Argentina   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   ...
# Armenia     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   ...
#
#              2005    2006    2007    2008    2009    2010    2011    2012  \
# geo
# Albania    1720.0  1220.0  1210.0  1620.0  1840.0  1940.0  2210.0  2120.0
# Algeria     887.0   859.0   891.0   944.0   863.0  1010.0  1120.0  1230.0
# Angola      109.0   144.0   133.0   172.0   189.0   206.0   207.0   219.0
# Argentina  2390.0  2360.0  2440.0  2750.0  2710.0  2850.0  2900.0  2970.0
# Armenia    1520.0  1640.0  1770.0  1670.0  1660.0  1730.0  1810.0  1890.0
#
#              2013    2014
# geo
# Albania    2530.0  2310.0
# Algeria    1270.0  1360.0
# Angola      280.0   312.0
# Argentina  2940.0  3050.0
# Armenia    1930.0  1970.0
#
# [5 rows x 55 columns]

# %%
electircity_use.rename(columns = {'2014':'electricity_use_per_person'}, inplace = True)

# %%
d4=electircity_use.pop('electricity_use_per_person')

# %%
df4=pd.DataFrame(d4)
df4.head()
# Out:
#            electricity_use_per_person
# geo
# Albania                        2310.0
# Algeria                        1360.0
# Angola                          312.0
# Argentina                      3050.0
# Armenia                        1970.0

# %%
forest=pd.read_csv('forest_coverage_percent.csv',index_col='geo')
forest.head()
# Out:
#               1990   1991   1992   1993   1994   1995   1996   1997   1998  \
# geo
# Afghanistan   2.07   2.07   2.07   2.07   2.07   2.07   2.07   2.07   2.07
# Albania      28.80  28.70  28.60  28.60  28.50  28.40  28.40  28.30  28.20
# Algeria       0.70   0.70   0.69   0.69   0.69   0.68   0.68   0.67   0.67
# Andorra      34.00  34.00  34.00  34.00  34.00  34.00  34.00  34.00  34.00
# Angola       48.90  48.80  48.70  48.60  48.50  48.40  48.30  48.20  48.10
#
#               1999  ...     2006   2007   2008   2009   2010   2011   2012  \
# geo                 ...
# Afghanistan   2.07  ...     2.07   2.07   2.07   2.07   2.07   2.07   2.07
# Albania      28.10  ...    28.50  28.50  28.40  28.40  28.30  28.30  28.30
# Algeria       0.67  ...     0.68   0.71   0.74   0.77   0.81   0.81   0.81
# Andorra      34.00  ...    34.00  34.00  34.00  34.00  34.00  34.00  34.00
# Angola       48.00  ...    47.30  47.20  47.10  47.00  46.90  46.80  46.70
#
#               2013   2014   2015
# geo
# Afghanistan   2.07   2.07   2.07
# Albania      28.20  28.20  28.20
# Algeria       0.81   0.82   0.82
# Andorra      34.00  34.00  34.00
# Angola       46.60  46.50  46.40
#
# [5 rows x 26 columns]

# %%
forest.rename(columns = {'2014':'forest_coverage_percent'}, inplace = True)

# %%
d5=forest.pop('forest_coverage_percent')

# %%
df5=pd.DataFrame(d5)
df5.head()
# Out:
#              forest_coverage_percent
# geo
# Afghanistan                     2.07
# Albania                        28.20
# Algeria                         0.82
# Andorra                        34.00
# Angola                         46.50

# %%
hydro=pd.read_csv('hydro_power_generation_per_person.csv',index_col='geo')
hydro.head()
# Out:
#            1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...   \
# geo                                                                    ...
# Albania     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Algeria     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Angola      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Argentina   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Armenia     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#               2002     2003     2004     2005     2006     2007     2008  \
# geo
# Albania    0.09770  0.13500  0.15000  0.14700  0.14800  0.07560  0.10300
# Algeria    0.00016  0.00071  0.00067  0.00145  0.00056  0.00057  0.00071
# Angola     0.00660  0.00692  0.00943  0.01160  0.01350  0.01230  0.01490
# Argentina  0.08190  0.07650  0.06830  0.07560  0.08360  0.06630  0.06590
# Armenia    0.04660  0.05570  0.05610  0.04970  0.05110  0.05180  0.05020
#
#               2009     2010  2011
# geo
# Albania    0.14000  0.20300   NaN
# Algeria    0.00075  0.00042   NaN
# Angola     0.01430  0.01590   NaN
# Argentina  0.07270  0.07150   NaN
# Armenia    0.05630  0.07110   NaN
#
# [5 rows x 52 columns]

# %% [markdown]
# now as in this dataframe 2014 column is not presentand we have to work only for column 2014 so we dont required this dataframe

# %%
income=pd.read_csv('income_per_person_gdppercapita_ppp_inflation_adjusted.csv',index_col='geo')
income.head()
# Out:
#              1800  1801  1802  1803  1804  1805  1806  1807  1808  1809  \
# geo
# Afghanistan   603   603   603   603   603   603   603   603   603   603
# Albania       667   667   667   667   667   668   668   668   668   668
# Algeria       715   716   717   718   719   720   721   722   723   724
# Andorra      1200  1200  1200  1200  1210  1210  1210  1210  1220  1220
# Angola        618   620   623   626   628   631   634   637   640   642
#
#              ...     2009   2010   2011   2012   2013   2014   2015   2016  \
# geo          ...
# Afghanistan  ...     1530   1610   1660   1840   1810   1780   1750   1740
# Albania      ...     9530   9930  10200  10400  10500  10700  11000  11400
# Algeria      ...    12600  12900  13000  13200  13300  13500  13700  14000
# Andorra      ...    41700  39000  42000  41900  43700  44900  46600  48200
# Angola       ...     5910   5900   5910   6000   6190   6260   6230   6030
#
#               2017   2018
# geo
# Afghanistan   1800   1870
# Albania      11900  12400
# Algeria      13800  13700
# Andorra      49800  51500
# Angola        5940   5850
#
# [5 rows x 219 columns]

# %%
income.rename(columns = {'2014':'income_per_person_gdppercapita_ppp_inflation_adjusted'}, inplace = True)

# %%
d6=income.pop('income_per_person_gdppercapita_ppp_inflation_adjusted')

# %%
df6=pd.DataFrame(d6);
df6.head();

# %%
indusrty=pd.read_csv('industry_percent_of_gdp.csv',index_col='geo')

# %%
indusrty.head()
# Out:
#              1960  1961  1962  1963  1964  1965  1966  1967  1968  1969  ...   \
# geo                                                                      ...
# Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Albania       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Algeria      29.4  29.5  31.7  40.8  42.7  42.2  46.5  47.8  47.7  47.8  ...
# Andorra       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# Angola        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#              2008  2009  2010  2011  2012  2013   2014   2015   2016  2017
# geo
# Afghanistan  26.7  21.8  21.0  22.6  21.0  20.4  21.10  22.00  21.70   NaN
# Albania      25.2  24.4  24.9  24.5  22.9  23.1  21.50  21.80  21.10  21.1
# Algeria      58.6  47.9  50.5  49.6  47.8  44.3  42.30  35.70  34.90  36.3
# Andorra      15.5  14.4  13.5  12.4  11.0  10.3   9.91   9.78   9.84   NaN
# Angola        NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN    NaN   NaN
#
# [5 rows x 58 columns]

# %%
indusrty.rename(columns = {'2014':'industry_percent_of_gdp'}, inplace = True)

# %%
d7=indusrty.pop('industry_percent_of_gdp')

# %%
df7=pd.DataFrame(d7)
df7.head()
# Out:
#              industry_percent_of_gdp
# geo
# Afghanistan                    21.10
# Albania                        21.50
# Algeria                        42.30
# Andorra                         9.91
# Angola                           NaN

# %%
naturalgas=pd.read_csv('natural_gas_production_per_person.csv',index_col='geo')

# %%
naturalgas.head()
# Out:
#              1970   1971   1972   1973   1974   1975   1976   1977   1978  \
# geo
# Algeria     0.157  0.161  0.198  0.256  0.288  0.344  0.422  0.392  0.591
# Argentina   0.226  0.232  0.224  0.228  0.221  0.247  0.251  0.250  0.233
# Australia   0.122  0.179  0.252  0.316  0.356  0.377  0.440  0.497  0.530
# Azerbaijan    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Bahrain     2.630  3.700  4.440  6.020  7.060  7.020  6.910  7.020  7.220
#
#              1979  ...     2007    2008   2009   2010   2011   2012    2013  \
# geo                ...
# Algeria     0.940  ...     2.23   2.220  2.020  2.000  2.020  1.950   1.940
# Argentina   0.271  ...     1.01   0.982  0.914  0.875  0.838  0.807   0.752
# Australia   0.603  ...     1.77   1.700  1.900  2.050  2.130  2.240   2.290
# Azerbaijan    NaN  ...     1.01   1.510  1.490  1.500  1.460  1.520   1.550
# Bahrain     7.560  ...    10.20  10.200  9.700  9.490  9.360  9.510  10.100
#
#               2014    2015   2016
# geo
# Algeria      1.920   1.910  2.020
# Argentina    0.742   0.756  0.786
# Australia    2.440   2.750  3.400
# Azerbaijan   1.660   1.680  1.620
# Bahrain     10.400  10.200  9.760
#
# [5 rows x 47 columns]

# %%
naturalgas.rename(columns = {'2014':'natural_gas_production_per_person'}, inplace = True)

# %%
d8=naturalgas.pop('natural_gas_production_per_person')

# %%
df8=pd.DataFrame(d8)
df8.head()
# Out:
#             natural_gas_production_per_person
# geo
# Algeria                                 1.920
# Argentina                               0.742
# Australia                               2.440
# Azerbaijan                              1.660
# Bahrain                                10.400

# %%
oilconsumption=pd.read_csv('oil_consumption_per_cap.csv',index_col='geo')
oilconsumption.head()
# Out:
#              1965   1966   1967   1968   1969   1970   1971   1972   1973  \
# geo
# Algeria     0.102  0.130  0.118  0.122  0.125  0.140  0.153  0.163  0.173
# Argentina   0.990  1.010  1.020  1.020  1.050  0.923  0.969  0.954  0.939
# Australia   1.330  1.550  1.650  1.750  1.760  1.900  1.960  1.970  2.070
# Austria     0.761  0.832  0.880  1.010  1.110  1.210  1.350  1.450  1.560
# Azerbaijan    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#              1974  ...     2007   2008   2009   2010   2011   2012   2013  \
# geo                ...
# Algeria     0.187  ...    0.376  0.402  0.419  0.411  0.430  0.448  0.458
# Argentina   0.930  ...    0.605  0.616  0.596  0.681  0.679  0.703  0.749
# Australia   2.160  ...    2.030  2.020  2.000  1.980  2.060  2.100  2.080
# Austria     1.390  ...    1.620  1.600  1.530  1.590  1.500  1.470  1.480
# Azerbaijan    NaN  ...    0.519  0.407  0.371  0.356  0.436  0.450  0.484
#
#              2014   2015   2016
# geo
# Algeria     0.452  0.488  0.465
# Argentina   0.729  0.741  0.728
# Australia   2.050  2.010  1.980
# Austria     1.440  1.440  1.450
# Azerbaijan  0.468  0.471  0.474
#
# [5 rows x 52 columns]

# %%
oilconsumption.rename(columns = {'2014':'oil_consumption_per_cap'}, inplace = True)

# %%
d9=oilconsumption.pop('oil_consumption_per_cap')

# %%
df9=pd.DataFrame(d9)
df9.head()
# Out:
#             oil_consumption_per_cap
# geo
# Algeria                       0.452
# Argentina                     0.729
# Australia                     2.050
# Austria                       1.440
# Azerbaijan                    0.468

# %%
oilproduction=pd.read_csv('oil_production_per_person.csv',index_col='geo')
oilproduction.head()
# Out:
#               1965    1966    1967   1968   1969   1970   1971   1972   1973  \
# geo
# Algeria     2.1000  2.6100  2.9300  3.120  3.170  3.310  2.480  3.260  3.220
# Angola      0.1060  0.1000  0.0837  0.115  0.370  0.747  0.826  0.995  1.120
# Argentina   0.6180  0.6480  0.6960  0.752  0.767  0.834  0.885  0.896  0.857
# Australia   0.0305  0.0382  0.0869  0.158  0.177  0.678  1.170  1.220  1.510
# Azerbaijan     NaN     NaN     NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#              1974  ...     2007   2008   2009   2010   2011   2012   2013  \
# geo                ...
# Algeria     2.910  ...    2.520  2.460  2.180  2.040  1.950  1.790  1.690
# Angola      1.140  ...    3.930  4.300  3.890  3.870  3.460  3.460  3.360
# Argentina   0.825  ...    0.957  0.937  0.834  0.809  0.742  0.738  0.717
# Australia   1.480  ...    1.170  1.130  1.030  1.110  0.958  0.937  0.769
# Azerbaijan    NaN  ...    4.880  5.050  5.650  5.630  4.990  4.680  4.630
#
#              2014   2015   2016
# geo
# Algeria     1.760  1.690  1.690
# Angola      3.080  3.180  3.050
# Argentina   0.695  0.687  0.657
# Australia   0.813  0.732  0.644
# Azerbaijan  4.430  4.330  4.220
#
# [5 rows x 52 columns]

# %%
oilproduction.rename(columns = {'2014':'oil_production_per_person'}, inplace = True)

# %%
d10=oilproduction.pop('oil_production_per_person')

# %%
df10=pd.DataFrame(d10)
df10.head()
# Out:
#             oil_production_per_person
# geo
# Algeria                         1.760
# Angola                          3.080
# Argentina                       0.695
# Australia                       0.813
# Azerbaijan                      4.430

# %%
yearlyCo2=pd.read_csv('yearly_co2_emissions_1000_tonnes.csv',index_col='geo')
yearlyCo2.head()
# Out:
#              1751  1752  1753  1754  1755  1756  1757  1758  1759  1760  \
# geo
# Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Algeria       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Andorra       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Angola        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#                ...         2005      2006      2007      2008      2009  \
# geo            ...
# Afghanistan    ...       1330.0    1650.0    2270.0    4210.0    6770.0
# Albania        ...       4250.0    3900.0    3930.0    4370.0    4380.0
# Algeria        ...     107000.0  101000.0  109000.0  110000.0  121000.0
# Andorra        ...        576.0     546.0     539.0     539.0     517.0
# Angola         ...      19200.0   22300.0   25200.0   25700.0   27800.0
#
#                  2010      2011      2012      2013      2014
# geo
# Afghanistan    8460.0   12200.0   10800.0   10000.0    9810.0
# Albania        4600.0    5240.0    4910.0    5060.0    5720.0
# Algeria      119000.0  121000.0  130000.0  134000.0  145000.0
# Andorra         517.0     491.0     488.0     477.0     462.0
# Angola        29100.0   30300.0   33400.0   32600.0   34800.0
#
# [5 rows x 264 columns]

# %%
yearlyCo2.rename(columns = {'2014':'yearly_co2_emissions_1000_tonnes'}, inplace = True)

# %%
d11=yearlyCo2.pop('yearly_co2_emissions_1000_tonnes')

# %%
df11=pd.DataFrame(d11)
df11.head()
# Out:
#              yearly_co2_emissions_1000_tonnes
# geo
# Afghanistan                            9810.0
# Albania                                5720.0
# Algeria                              145000.0
# Andorra                                 462.0
# Angola                                34800.0

# %% [markdown]
# Now we are merging dataframes by taking two at a time.

# %%
dff1=pd.merge(df1, df2, left_index=True, right_index=True)

# %%
dff1.head()
# Out:
#             co2_emissions_tonnes_per_person  coal_consumption_per_cap
# geo
# Algeria                                3.72                   0.00458
# Argentina                              4.75                   0.03460
# Australia                             15.40                   1.82000
# Austria                                6.80                   0.34700
# Azerbaijan                             3.94                   0.00017

# %%
dff2=pd.merge(df3,df4,left_index=True,right_index=True)
dff2.head()
# Out:
#             electricity_generation_per_person  electricity_use_per_person
# geo
# Algeria                                  1640                      1360.0
# Argentina                                3290                      3050.0
# Australia                               10500                     10100.0
# Austria                                  7540                      8360.0
# Azerbaijan                               2600                      2200.0

# %%
dff3=pd.merge(df5, df6, left_index=True, right_index=True)
dff3.head()
# Out:
#              forest_coverage_percent  \
# geo
# Afghanistan                     2.07
# Albania                        28.20
# Algeria                         0.82
# Andorra                        34.00
# Angola                         46.50
#
#              income_per_person_gdppercapita_ppp_inflation_adjusted
# geo
# Afghanistan                                               1780
# Albania                                                  10700
# Algeria                                                  13500
# Andorra                                                  44900
# Angola                                                    6260

# %%
dff4=pd.merge(df7, df8, left_index=True, right_index=True)

# %%
dff4.head()
# Out:
#             industry_percent_of_gdp  natural_gas_production_per_person
# geo
# Algeria                        42.3                              1.920
# Argentina                      24.3                              0.742
# Australia                      25.4                              2.440
# Azerbaijan                     53.6                              1.660
# Bahrain                        46.5                             10.400

# %%
dff5=pd.merge(df9, df10, left_index=True, right_index=True)
dff5.head()
# Out:
#             oil_consumption_per_cap  oil_production_per_person
# geo
# Algeria                       0.452                      1.760
# Argentina                     0.729                      0.695
# Australia                     2.050                      0.813
# Azerbaijan                    0.468                      4.430
# Brazil                        0.737                      0.600

# %%
dff6=pd.merge(dff5, df11, left_index=True, right_index=True)

# %%
dff6.head()
# Out:
#             oil_consumption_per_cap  oil_production_per_person  \
# geo
# Algeria                       0.452                      1.760
# Argentina                     0.729                      0.695
# Australia                     2.050                      0.813
# Azerbaijan                    0.468                      4.430
# Brazil                        0.737                      0.600
#
#             yearly_co2_emissions_1000_tonnes
# geo
# Algeria                             145000.0
# Argentina                           204000.0
# Australia                           361000.0
# Azerbaijan                           37500.0
# Brazil                              530000.0

# %%
dff7=pd.merge(dff4, dff6, left_index=True, right_index=True)

# %%
dff7.head()
# Out:
#             industry_percent_of_gdp  natural_gas_production_per_person  \
# geo
# Algeria                        42.3                              1.920
# Argentina                      24.3                              0.742
# Australia                      25.4                              2.440
# Azerbaijan                     53.6                              1.660
# Brazil                         20.5                              0.100
#
#             oil_consumption_per_cap  oil_production_per_person  \
# geo
# Algeria                       0.452                      1.760
# Argentina                     0.729                      0.695
# Australia                     2.050                      0.813
# Azerbaijan                    0.468                      4.430
# Brazil                        0.737                      0.600
#
#             yearly_co2_emissions_1000_tonnes
# geo
# Algeria                             145000.0
# Argentina                           204000.0
# Australia                           361000.0
# Azerbaijan                           37500.0
# Brazil                              530000.0

# %%
dff8=pd.merge(dff7, dff3, left_index=True, right_index=True)

# %%
dff8.head()
# Out:
#             industry_percent_of_gdp  natural_gas_production_per_person  \
# geo
# Algeria                        42.3                              1.920
# Argentina                      24.3                              0.742
# Australia                      25.4                              2.440
# Azerbaijan                     53.6                              1.660
# Brazil                         20.5                              0.100
#
#             oil_consumption_per_cap  oil_production_per_person  \
# geo
# Algeria                       0.452                      1.760
# Argentina                     0.729                      0.695
# Australia                     2.050                      0.813
# Azerbaijan                    0.468                      4.430
# Brazil                        0.737                      0.600
#
#             yearly_co2_emissions_1000_tonnes  forest_coverage_percent  \
# geo
# Algeria                             145000.0                     0.82
# Argentina                           204000.0                    10.00
# Australia                           361000.0                    16.20
# Azerbaijan                           37500.0                    13.50
# Brazil                              530000.0                    59.20
#
#             income_per_person_gdppercapita_ppp_inflation_adjusted
# geo
# Algeria                                                 13500
# Argentina                                               18800
# Australia                                               43400
# Azerbaijan                                              16700
# Brazil                                                  15400

# %%
dff9=pd.merge(dff8, dff2, left_index=True, right_index=True)

# %%
dff9.head()
# Out:
#             industry_percent_of_gdp  natural_gas_production_per_person  \
# geo
# Algeria                        42.3                              1.920
# Argentina                      24.3                              0.742
# Australia                      25.4                              2.440
# Azerbaijan                     53.6                              1.660
# Brazil                         20.5                              0.100
#
#             oil_consumption_per_cap  oil_production_per_person  \
# geo
# Algeria                       0.452                      1.760
# Argentina                     0.729                      0.695
# Australia                     2.050                      0.813
# Azerbaijan                    0.468                      4.430
# Brazil                        0.737                      0.600
#
#             yearly_co2_emissions_1000_tonnes  forest_coverage_percent  \
# geo
# Algeria                             145000.0                     0.82
# Argentina                           204000.0                    10.00
# Australia                           361000.0                    16.20
# Azerbaijan                           37500.0                    13.50
# Brazil                              530000.0                    59.20
#
#             income_per_person_gdppercapita_ppp_inflation_adjusted  \
# geo
# Algeria                                                 13500
# Argentina                                               18800
# Australia                                               43400
# Azerbaijan                                              16700
# Brazil                                                  15400
#
#             electricity_generation_per_person  electricity_use_per_person
# geo
# Algeria                                  1640                      1360.0
# Argentina                                3290                      3050.0
# Australia                               10500                     10100.0
# Azerbaijan                               2600                      2200.0
# Brazil                                   2890                      2600.0

# %%
df=pd.merge(dff1, dff9, left_index=True, right_index=True)

# %% [markdown]
# Finally we get dataframe by merging different dataframes and this dataframe is our required dataframe.

# %%
df.head()
# Out:
#             co2_emissions_tonnes_per_person  coal_consumption_per_cap  \
# geo
# Algeria                                3.72                   0.00458
# Argentina                              4.75                   0.03460
# Australia                             15.40                   1.82000
# Azerbaijan                             3.94                   0.00017
# Brazil                                 2.59                   0.08580
#
#             industry_percent_of_gdp  natural_gas_production_per_person  \
# geo
# Algeria                        42.3                              1.920
# Argentina                      24.3                              0.742
# Australia                      25.4                              2.440
# Azerbaijan                     53.6                              1.660
# Brazil                         20.5                              0.100
#
#             oil_consumption_per_cap  oil_production_per_person  \
# geo
# Algeria                       0.452                      1.760
# Argentina                     0.729                      0.695
# Australia                     2.050                      0.813
# Azerbaijan                    0.468                      4.430
# Brazil                        0.737                      0.600
#
#             yearly_co2_emissions_1000_tonnes  forest_coverage_percent  \
# geo
# Algeria                             145000.0                     0.82
# Argentina                           204000.0                    10.00
# Australia                           361000.0                    16.20
# Azerbaijan                           37500.0                    13.50
# Brazil                              530000.0                    59.20
#
#             income_per_person_gdppercapita_ppp_inflation_adjusted  \
# geo
# Algeria                                                 13500
# Argentina                                               18800
# Australia                                               43400
# Azerbaijan                                              16700
# Brazil                                                  15400
#
#             electricity_generation_per_person  electricity_use_per_person
# geo
# Algeria                                  1640                      1360.0
# Argentina                                3290                      3050.0
# Australia                               10500                     10100.0
# Azerbaijan                               2600                      2200.0
# Brazil                                   2890                      2600.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, Algeria to Vietnam
# Data columns (total 11 columns):
# co2_emissions_tonnes_per_person                          33 non-null float64
# coal_consumption_per_cap                                 33 non-null float64
# industry_percent_of_gdp                                  33 non-null float64
# natural_gas_production_per_person                        33 non-null float64
# oil_consumption_per_cap                                  33 non-null float64
# oil_production_per_person                                33 non-null float64
# yearly_co2_emissions_1000_tonnes                         33 non-null float64
# forest_coverage_percent                                  33 non-null float64
# income_per_person_gdppercapita_ppp_inflation_adjusted    33 non-null int64
# electricity_generation_per_person                        33 non-null int64
# electricity_use_per_person                               33 non-null float64
# dtypes: float64(9), int64(2)
# memory usage: 3.1+ KB

# %% [markdown]
# # Checking for outliers

# %%
df.describe()
# Out:
#        co2_emissions_tonnes_per_person  coal_consumption_per_cap  \
# count                        33.000000                 33.000000
# mean                         10.051515                  0.357886
# std                          10.074812                  0.570206
# min                           1.730000                  0.000000
# 25%                           3.500000                  0.006410
# 50%                           6.030000                  0.161000
# 75%                          14.200000                  0.457000
# max                          45.400000                  2.340000
#
#        industry_percent_of_gdp  natural_gas_production_per_person  \
# count                33.000000                          33.000000
# mean                 37.066667                           4.979970
# std                  13.844509                          12.396831
# min                  17.800000                           0.021200
# 25%                  27.700000                           0.413000
# 50%                  33.200000                           0.964000
# 75%                  42.300000                           2.990000
# max                  70.500000                          66.000000
#
#        oil_consumption_per_cap  oil_production_per_person  \
# count                33.000000                  33.000000
# mean                  1.405527                   5.141948
# std                   1.453000                   9.514454
# min                   0.088400                   0.032200
# 25%                   0.448000                   0.237000
# 50%                   0.936000                   1.100000
# 75%                   1.520000                   4.430000
# max                   5.550000                  39.700000
#
#        yearly_co2_emissions_1000_tonnes  forest_coverage_percent  \
# count                      3.300000e+01                33.000000
# mean                       8.042576e+05                26.003333
# std                        1.960110e+06                20.872529
# min                        3.350000e+04                 0.000000
# 25%                        9.540000e+04                 7.600000
# 50%                        2.110000e+05                23.700000
# 75%                        4.800000e+05                45.400000
# max                        1.030000e+07                67.500000
#
#        income_per_person_gdppercapita_ppp_inflation_adjusted  \
# count                                          33.000000
# mean                                        29230.606061
# std                                         24558.759504
# min                                          5370.000000
# 25%                                         13500.000000
# 50%                                         18800.000000
# 75%                                         42900.000000
# max                                        121000.000000
#
#        electricity_generation_per_person  electricity_use_per_person
# count                          33.000000                   33.000000
# mean                         6372.848485                 5769.030303
# std                          6226.084023                 5441.441471
# min                           896.000000                  806.000000
# 25%                          2440.000000                 2090.000000
# 50%                          3680.000000                 3050.000000
# 75%                          7360.000000                 7130.000000
# max                         27600.000000                23000.000000

# %%
# data visualization
from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# This is quite hard to read, and we can rather plot correlations between variables. Also, a heatmap is pretty useful to visualise multiple correlations in one plot.

# %%
# correlation matrix
cor = df.corr()
cor
# Out:
#                                                     co2_emissions_tonnes_per_person  \
# co2_emissions_tonnes_per_person                                            1.000000
# coal_consumption_per_cap                                                   0.072586
# industry_percent_of_gdp                                                    0.585031
# natural_gas_production_per_person                                          0.789657
# oil_consumption_per_cap                                                    0.758837
# oil_production_per_person                                                  0.730895
# yearly_co2_emissions_1000_tonnes                                          -0.021843
# forest_coverage_percent                                                   -0.303634
# income_per_person_gdppercapita_ppp_inflation_ad...                         0.819585
# electricity_generation_per_person                                          0.616939
# electricity_use_per_person                                                 0.655008
#
#                                                     coal_consumption_per_cap  \
# co2_emissions_tonnes_per_person                                     0.072586
# coal_consumption_per_cap                                            1.000000
# industry_percent_of_gdp                                            -0.321454
# natural_gas_production_per_person                                  -0.169961
# oil_consumption_per_cap                                            -0.037279
# oil_production_per_person                                          -0.186947
# yearly_co2_emissions_1000_tonnes                                    0.463521
# forest_coverage_percent                                            -0.063724
# income_per_person_gdppercapita_ppp_inflation_ad...                  0.042978
# electricity_generation_per_person                                   0.130728
# electricity_use_per_person                                          0.173286
#
#                                                     industry_percent_of_gdp  \
# co2_emissions_tonnes_per_person                                    0.585031
# coal_consumption_per_cap                                          -0.321454
# industry_percent_of_gdp                                            1.000000
# natural_gas_production_per_person                                  0.505993
# oil_consumption_per_cap                                            0.541264
# oil_production_per_person                                          0.708196
# yearly_co2_emissions_1000_tonnes                                  -0.084172
# forest_coverage_percent                                           -0.387368
# income_per_person_gdppercapita_ppp_inflation_ad...                 0.398804
# electricity_generation_per_person                                  0.234565
# electricity_use_per_person                                         0.227236
#
#                                                     natural_gas_production_per_person  \
# co2_emissions_tonnes_per_person                                              0.789657
# coal_consumption_per_cap                                                    -0.169961
# industry_percent_of_gdp                                                      0.505993
# natural_gas_production_per_person                                            1.000000
# oil_consumption_per_cap                                                      0.395971
# oil_production_per_person                                                    0.576356
# yearly_co2_emissions_1000_tonnes                                            -0.120514
# forest_coverage_percent                                                     -0.174757
# income_per_person_gdppercapita_ppp_inflation_ad...                           0.712562
# electricity_generation_per_person                                            0.470693
# electricity_use_per_person                                                   0.488956
#
#                                                     oil_consumption_per_cap  \
# co2_emissions_tonnes_per_person                                    0.758837
# coal_consumption_per_cap                                          -0.037279
# industry_percent_of_gdp                                            0.541264
# natural_gas_production_per_person                                  0.395971
# oil_consumption_per_cap                                            1.000000
# oil_production_per_person                                          0.852679
# yearly_co2_emissions_1000_tonnes                                  -0.067199
# forest_coverage_percent                                           -0.365946
# income_per_person_gdppercapita_ppp_inflation_ad...                 0.824429
# electricity_generation_per_person                                  0.734216
# electricity_use_per_person                                         0.754879
#
#                                                     oil_production_per_person  \
# co2_emissions_tonnes_per_person                                      0.730895
# coal_consumption_per_cap                                            -0.186947
# industry_percent_of_gdp                                              0.708196
# natural_gas_production_per_person                                    0.576356
# oil_consumption_per_cap                                              0.852679
# oil_production_per_person                                            1.000000
# yearly_co2_emissions_1000_tonnes                                    -0.146682
# forest_coverage_percent                                             -0.392621
# income_per_person_gdppercapita_ppp_inflation_ad...                   0.820701
# electricity_generation_per_person                                    0.691894
# electricity_use_per_person                                           0.696951
#
#                                                     yearly_co2_emissions_1000_tonnes  \
# co2_emissions_tonnes_per_person                                            -0.021843
# coal_consumption_per_cap                                                    0.463521
# industry_percent_of_gdp                                                    -0.084172
# natural_gas_production_per_person                                          -0.120514
# oil_consumption_per_cap                                                    -0.067199
# oil_production_per_person                                                  -0.146682
# yearly_co2_emissions_1000_tonnes                                            1.000000
# forest_coverage_percent                                                     0.025110
# income_per_person_gdppercapita_ppp_inflation_ad...                         -0.076267
# electricity_generation_per_person                                           0.006405
# electricity_use_per_person                                                  0.023182
#
#                                                     forest_coverage_percent  \
# co2_emissions_tonnes_per_person                                   -0.303634
# coal_consumption_per_cap                                          -0.063724
# industry_percent_of_gdp                                           -0.387368
# natural_gas_production_per_person                                 -0.174757
# oil_consumption_per_cap                                           -0.365946
# oil_production_per_person                                         -0.392621
# yearly_co2_emissions_1000_tonnes                                   0.025110
# forest_coverage_percent                                            1.000000
# income_per_person_gdppercapita_ppp_inflation_ad...                -0.330581
# electricity_generation_per_person                                 -0.164724
# electricity_use_per_person                                        -0.182132
#
#                                                     income_per_person_gdppercapita_ppp_inflation_adjusted  \
# co2_emissions_tonnes_per_person                                                              0.819585
# coal_consumption_per_cap                                                                     0.042978
# industry_percent_of_gdp                                                                      0.398804
# natural_gas_production_per_person                                                            0.712562
# oil_consumption_per_cap                                                                      0.824429
# oil_production_per_person                                                                    0.820701
# yearly_co2_emissions_1000_tonnes                                                            -0.076267
# forest_coverage_percent                                                                     -0.330581
# income_per_person_gdppercapita_ppp_inflation_ad...                                           1.000000
# electricity_generation_per_person                                                            0.807916
# electricity_use_per_person                                                                   0.839071
#
#                                                     electricity_generation_per_person  \
# co2_emissions_tonnes_per_person                                              0.616939
# coal_consumption_per_cap                                                     0.130728
# industry_percent_of_gdp                                                      0.234565
# natural_gas_production_per_person                                            0.470693
# oil_consumption_per_cap                                                      0.734216
# oil_production_per_person                                                    0.691894
# yearly_co2_emissions_1000_tonnes                                             0.006405
# forest_coverage_percent                                                     -0.164724
# income_per_person_gdppercapita_ppp_inflation_ad...                           0.807916
# electricity_generation_per_person                                            1.000000
# electricity_use_per_person                                                   0.995825
#
#                                                     electricity_use_per_person
# co2_emissions_tonnes_per_person                                       0.655008
# coal_consumption_per_cap                                              0.173286
# industry_percent_of_gdp                                               0.227236
# natural_gas_production_per_person                                     0.488956
# oil_consumption_per_cap                                               0.754879
# oil_production_per_person                                             0.696951
# yearly_co2_emissions_1000_tonnes                                      0.023182
# forest_coverage_percent                                              -0.182132
# income_per_person_gdppercapita_ppp_inflation_ad...                    0.839071
# electricity_generation_per_person                                     0.995825
# electricity_use_per_person                                            1.000000

# %%
# plotting correlations on a heatmap

# figure size
plt.figure(figsize=(16,8))

# heatmap
sns.heatmap(cor, cmap="YlGnBu", annot=True)
plt.show()

# %%
# now from this it is clear that forest_coverage_percent is negatively correlated so we should drop it.
df.drop('forest_coverage_percent',axis=1,inplace=True)

# %%
#now again we see on correlation matrix
cor = df.corr()
cor
# Out:
#                                                     co2_emissions_tonnes_per_person  \
# co2_emissions_tonnes_per_person                                            1.000000
# coal_consumption_per_cap                                                   0.072586
# industry_percent_of_gdp                                                    0.585031
# natural_gas_production_per_person                                          0.789657
# oil_consumption_per_cap                                                    0.758837
# oil_production_per_person                                                  0.730895
# yearly_co2_emissions_1000_tonnes                                          -0.021843
# income_per_person_gdppercapita_ppp_inflation_ad...                         0.819585
# electricity_generation_per_person                                          0.616939
# electricity_use_per_person                                                 0.655008
#
#                                                     coal_consumption_per_cap  \
# co2_emissions_tonnes_per_person                                     0.072586
# coal_consumption_per_cap                                            1.000000
# industry_percent_of_gdp                                            -0.321454
# natural_gas_production_per_person                                  -0.169961
# oil_consumption_per_cap                                            -0.037279
# oil_production_per_person                                          -0.186947
# yearly_co2_emissions_1000_tonnes                                    0.463521
# income_per_person_gdppercapita_ppp_inflation_ad...                  0.042978
# electricity_generation_per_person                                   0.130728
# electricity_use_per_person                                          0.173286
#
#                                                     industry_percent_of_gdp  \
# co2_emissions_tonnes_per_person                                    0.585031
# coal_consumption_per_cap                                          -0.321454
# industry_percent_of_gdp                                            1.000000
# natural_gas_production_per_person                                  0.505993
# oil_consumption_per_cap                                            0.541264
# oil_production_per_person                                          0.708196
# yearly_co2_emissions_1000_tonnes                                  -0.084172
# income_per_person_gdppercapita_ppp_inflation_ad...                 0.398804
# electricity_generation_per_person                                  0.234565
# electricity_use_per_person                                         0.227236
#
#                                                     natural_gas_production_per_person  \
# co2_emissions_tonnes_per_person                                              0.789657
# coal_consumption_per_cap                                                    -0.169961
# industry_percent_of_gdp                                                      0.505993
# natural_gas_production_per_person                                            1.000000
# oil_consumption_per_cap                                                      0.395971
# oil_production_per_person                                                    0.576356
# yearly_co2_emissions_1000_tonnes                                            -0.120514
# income_per_person_gdppercapita_ppp_inflation_ad...                           0.712562
# electricity_generation_per_person                                            0.470693
# electricity_use_per_person                                                   0.488956
#
#                                                     oil_consumption_per_cap  \
# co2_emissions_tonnes_per_person                                    0.758837
# coal_consumption_per_cap                                          -0.037279
# industry_percent_of_gdp                                            0.541264
# natural_gas_production_per_person                                  0.395971
# oil_consumption_per_cap                                            1.000000
# oil_production_per_person                                          0.852679
# yearly_co2_emissions_1000_tonnes                                  -0.067199
# income_per_person_gdppercapita_ppp_inflation_ad...                 0.824429
# electricity_generation_per_person                                  0.734216
# electricity_use_per_person                                         0.754879
#
#                                                     oil_production_per_person  \
# co2_emissions_tonnes_per_person                                      0.730895
# coal_consumption_per_cap                                            -0.186947
# industry_percent_of_gdp                                              0.708196
# natural_gas_production_per_person                                    0.576356
# oil_consumption_per_cap                                              0.852679
# oil_production_per_person                                            1.000000
# yearly_co2_emissions_1000_tonnes                                    -0.146682
# income_per_person_gdppercapita_ppp_inflation_ad...                   0.820701
# electricity_generation_per_person                                    0.691894
# electricity_use_per_person                                           0.696951
#
#                                                     yearly_co2_emissions_1000_tonnes  \
# co2_emissions_tonnes_per_person                                            -0.021843
# coal_consumption_per_cap                                                    0.463521
# industry_percent_of_gdp                                                    -0.084172
# natural_gas_production_per_person                                          -0.120514
# oil_consumption_per_cap                                                    -0.067199
# oil_production_per_person                                                  -0.146682
# yearly_co2_emissions_1000_tonnes                                            1.000000
# income_per_person_gdppercapita_ppp_inflation_ad...                         -0.076267
# electricity_generation_per_person                                           0.006405
# electricity_use_per_person                                                  0.023182
#
#                                                     income_per_person_gdppercapita_ppp_inflation_adjusted  \
# co2_emissions_tonnes_per_person                                                              0.819585
# coal_consumption_per_cap                                                                     0.042978
# industry_percent_of_gdp                                                                      0.398804
# natural_gas_production_per_person                                                            0.712562
# oil_consumption_per_cap                                                                      0.824429
# oil_production_per_person                                                                    0.820701
# yearly_co2_emissions_1000_tonnes                                                            -0.076267
# income_per_person_gdppercapita_ppp_inflation_ad...                                           1.000000
# electricity_generation_per_person                                                            0.807916
# electricity_use_per_person                                                                   0.839071
#
#                                                     electricity_generation_per_person  \
# co2_emissions_tonnes_per_person                                              0.616939
# coal_consumption_per_cap                                                     0.130728
# industry_percent_of_gdp                                                      0.234565
# natural_gas_production_per_person                                            0.470693
# oil_consumption_per_cap                                                      0.734216
# oil_production_per_person                                                    0.691894
# yearly_co2_emissions_1000_tonnes                                             0.006405
# income_per_person_gdppercapita_ppp_inflation_ad...                           0.807916
# electricity_generation_per_person                                            1.000000
# electricity_use_per_person                                                   0.995825
#
#                                                     electricity_use_per_person
# co2_emissions_tonnes_per_person                                       0.655008
# coal_consumption_per_cap                                              0.173286
# industry_percent_of_gdp                                               0.227236
# natural_gas_production_per_person                                     0.488956
# oil_consumption_per_cap                                               0.754879
# oil_production_per_person                                             0.696951
# yearly_co2_emissions_1000_tonnes                                      0.023182
# income_per_person_gdppercapita_ppp_inflation_ad...                    0.839071
# electricity_generation_per_person                                     0.995825
# electricity_use_per_person                                            1.000000

# %%
# plotting correlations on a heatmap

# figure size
plt.figure(figsize=(16,8))

# heatmap
sns.heatmap(cor, cmap="YlGnBu", annot=True)
plt.show()

# %%
#Applying IQR method 
q1 = df.quantile(0.25)
q3 = df.quantile(0.75)
IQR = q3 - q1
df = df[~((df < (q1 - 1.5 * IQR)) |(df > (q3 + 1.5 * IQR))).any(axis=1)]

# %%
#Checking Shape
df.shape
# Out:
# (19, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19 entries, Algeria to Vietnam
# Data columns (total 10 columns):
# co2_emissions_tonnes_per_person                          19 non-null float64
# coal_consumption_per_cap                                 19 non-null float64
# industry_percent_of_gdp                                  19 non-null float64
# natural_gas_production_per_person                        19 non-null float64
# oil_consumption_per_cap                                  19 non-null float64
# oil_production_per_person                                19 non-null float64
# yearly_co2_emissions_1000_tonnes                         19 non-null float64
# income_per_person_gdppercapita_ppp_inflation_adjusted    19 non-null int64
# electricity_generation_per_person                        19 non-null int64
# electricity_use_per_person                               19 non-null float64
# dtypes: float64(8), int64(2)
# memory usage: 1.6+ KB

# %% [markdown]
# # Data Preparation

# %% [markdown]
# Data Preparation
# Let's now prepare the data and build the model.

# %%
X = df.loc[:, ['coal_consumption_per_cap','industry_percent_of_gdp','natural_gas_production_per_person','oil_consumption_per_cap','oil_production_per_person','yearly_co2_emissions_1000_tonnes','income_per_person_gdppercapita_ppp_inflation_adjusted','electricity_generation_per_person','electricity_use_per_person']]

# %%
X.head()
# Out:
#             coal_consumption_per_cap  industry_percent_of_gdp  \
# geo
# Algeria                      0.00458                     42.3
# Argentina                    0.03460                     24.3
# Azerbaijan                   0.00017                     53.6
# Brazil                       0.08580                     20.5
# Colombia                     0.11000                     32.7
#
#             natural_gas_production_per_person  oil_consumption_per_cap  \
# geo
# Algeria                                 1.920                    0.452
# Argentina                               0.742                    0.729
# Azerbaijan                              1.660                    0.468
# Brazil                                  0.100                    0.737
# Colombia                                0.222                    0.309
#
#             oil_production_per_person  yearly_co2_emissions_1000_tonnes  \
# geo
# Algeria                         1.760                          145000.0
# Argentina                       0.695                          204000.0
# Azerbaijan                      4.430                           37500.0
# Brazil                          0.600                          530000.0
# Colombia                        1.090                           84100.0
#
#             income_per_person_gdppercapita_ppp_inflation_adjusted  \
# geo
# Algeria                                                 13500
# Argentina                                               18800
# Azerbaijan                                              16700
# Brazil                                                  15400
# Colombia                                                12700
#
#             electricity_generation_per_person  electricity_use_per_person
# geo
# Algeria                                  1640                      1360.0
# Argentina                                3290                      3050.0
# Azerbaijan                               2600                      2200.0
# Brazil                                   2890                      2600.0
# Colombia                                 1560                      1290.0

# %%
y = df['co2_emissions_tonnes_per_person']

# %%
y.head()
# Out:
# geo
# Algeria       3.72
# Argentina     4.75
# Azerbaijan    3.94
# Brazil        2.59
# Colombia      1.76
# Name: co2_emissions_tonnes_per_person, dtype: float64

# %% [markdown]
# # Model Building and Evaluation

# %%
# scaling the features
from sklearn.preprocessing import scale

# storing column names in cols, since column names are (annoyingly) lost after 
# scaling (the df is converted to a numpy array)
cols = X.columns
X = pd.DataFrame(scale(X))
X.columns = cols
X.columns
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by the scale function.
#   import sys
# Index(['coal_consumption_per_cap', 'industry_percent_of_gdp',
#        'natural_gas_production_per_person', 'oil_consumption_per_cap',
#        'oil_production_per_person', 'yearly_co2_emissions_1000_tonnes',
#        'income_per_person_gdppercapita_ppp_inflation_adjusted',
#        'electricity_generation_per_person', 'electricity_use_per_person'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.7,test_size = 0.3, random_state=100)

# %%
# list of alphas to tune
params = {'alpha': [ 0.01, 0.05, 0.1, 
 0.2, 0.8, 0.9, 1.0, 2.0]}
folds = 5
lasso = Lasso()
# cross validation
model_cv = GridSearchCV(estimator = lasso, 
                        param_grid = params, 
                        scoring= 'neg_mean_absolute_error', 
                        cv = 7, 
                        return_train_score=True,
                        verbose = 1)            

model_cv.fit(X_train, y_train)
# Out:
# Fitting 7 folds for each of 8 candidates, totalling 56 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed:    0.2s finished
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=7, error_score='raise-deprecating',
#        estimator=Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'alpha': [0.01, 0.05, 0.1, 0.2, 0.8, 0.9, 1.0, 2.0]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='neg_mean_absolute_error', verbose=1)

# %%
cv_results = pd.DataFrame(model_cv.cv_results_)
cv_results.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0       0.002447      0.000496         0.001106        0.000334        0.01
# 1       0.002275      0.000453         0.000717        0.000453        0.05
# 2       0.002442      0.001184         0.001117        0.000299         0.1
# 3       0.002337      0.000436         0.001419        0.000499         0.2
# 4       0.002435      0.000483         0.000984        0.000033         0.8
#
#             params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'alpha': 0.01}          -0.804965          -1.273025          -1.416563
# 1  {'alpha': 0.05}          -0.370343          -0.974308          -0.917229
# 2   {'alpha': 0.1}          -0.351356          -1.040341          -0.983077
# 3   {'alpha': 0.2}          -0.344339          -1.064001          -0.966893
# 4   {'alpha': 0.8}          -1.078993          -0.894887          -0.151663
#
#    split3_test_score       ...         rank_test_score  split0_train_score  \
# 0          -1.252922       ...                       6           -0.304800
# 1          -0.534002       ...                       2           -0.390082
# 2          -0.488506       ...                       1           -0.418494
# 3          -0.637730       ...                       3           -0.501975
# 4          -2.057464       ...                       4           -0.921817
#
#    split1_train_score  split2_train_score  split3_train_score  \
# 0           -0.270156           -0.330945           -0.266904
# 1           -0.330757           -0.344209           -0.350077
# 2           -0.369030           -0.387228           -0.393475
# 3           -0.456242           -0.450660           -0.500690
# 4           -0.809661           -0.932763           -0.925654
#
#    split4_train_score  split5_train_score  split6_train_score  \
# 0           -0.361196           -0.154957           -0.259899
# 1           -0.387622           -0.188892           -0.286290
# 2           -0.436751           -0.233351           -0.340314
# 3           -0.521826           -0.348859           -0.434800
# 4           -0.872690           -0.892840           -0.855738
#
#    mean_train_score  std_train_score
# 0         -0.278408         0.061055
# 1         -0.325418         0.064598
# 2         -0.368378         0.062326
# 3         -0.459293         0.053885
# 4         -0.887309         0.041399
#
# [5 rows x 25 columns]

# %%
# plotting mean test and train scoes with alpha 
cv_results['param_alpha'] = cv_results['param_alpha'].astype('float32')

# plotting
plt.plot(cv_results['param_alpha'], cv_results['mean_train_score'])
plt.plot(cv_results['param_alpha'], cv_results['mean_test_score'])
plt.xlabel('alpha')
plt.ylabel('Negative Mean Absolute Error')

plt.title("Negative Mean Absolute Error and alpha")
plt.legend(['train score', 'test score'], loc='upper left')
plt.show()

# %%
alpha =0.01

lasso = Lasso(alpha=alpha)
        
lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.01, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
lasso.coef_
# Out:
# array([ 0.06687721,  0.25555553,  0.93478149,  0.17609756, -0.20150787,
#         0.49535097, -0.        ,  1.34951223,  0.        ])

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, model_cv.predict(X_test))
# Out:
# 0.48751017821885156

# %%
#Importing Linear regression Libraries
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
Linear_model= LinearRegression()

# %%
#now we creating Linear Model
Linear_model.fit(X_train,y_train)
pred = Linear_model.predict(X_test)
pred[:10]
# Out:
# array([6.38249686, 3.62003115, 4.29230985, 1.32588428, 3.78845719,
#        3.99720296])

# %%
#Importing mean_squared_error and calculating meansquare for linear
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test,pred)**(0.5))
# Out:
# 0.8887442223615221

# %%
#Importing r2 score
from sklearn.metrics import r2_score

# %%
#Checking r2 score for linear
r2_score(y_test,prediction)
# Out:
# 0.6499616968145859

# %%
#Creating Lasso model for prediction
lasso_model = Lasso(alpha=0.00001)
lasso_model.fit(X_train,y_train)
pred2 = lasso_model.predict(X_test)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
#Checking Mean squared error for Lasso
print(mean_squared_error(y_test,pred2)**(0.5))
# Out:
# 0.8877982278062921

# %%
#Checking r2 score for Lasso
r2_score(y_test,pred2)
# Out:
# 0.6507064737438435

# %%
We can see that our lasso model's r2 and mean squared value are almost same as linear model on alpha 0.01.
